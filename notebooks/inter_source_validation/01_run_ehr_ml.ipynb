# %% [markdown]
# # Run EHR-ML

# %% [markdown]
# ## Evaluate mortality prediction for eICU data

# %%
import os


for (wb, wa) in [(30, 30)]:
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------- wb: ' + str(wb) + ' --- wa: ' + str(wa) + ' -------------------------------------------------------------')
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_ML_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrml.ensemble.Evaluate ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/data/data_matrix_eicu.csv -tc "death_0_30_adm" -ic "person_id" "visit_occurrence_id" -mdc "measurement_date" -adc "visit_start_date_adm" -wb ''' + str(wb) + ''' -wa ''' + str(wa) + ''' -sp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/evaluation/eicu_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.json;'''
        )
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------- wb: 30 --- wa: 30 -------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2024-09-16 11:07:33,075 - EHR-ML - INFO - Parsing command line arguments
# 2024-09-16 11:07:33,077 - EHR-ML - INFO - args.data_file: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/experiments/inter_source_validation/data/data_matrix_eicu.csv
# 2024-09-16 11:07:33,077 - EHR-ML - INFO - args.target_column: death_0_30_adm
# 2024-09-16 11:07:33,077 - EHR-ML - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# ...

# %% [markdown]
# ## Evaluate mortality prediction for MIMIC data

# %%
import os


for (wb, wa) in [(30, 30)]:
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------- wb: ' + str(wb) + ' --- wa: ' + str(wa) + ' -------------------------------------------------------------')
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_ML_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrml.ensemble.Evaluate ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/data/data_matrix_mimic.csv -tc "death_0_30_adm" -ic "person_id" "visit_occurrence_id" -mdc "measurement_date" -adc "visit_start_datetime_adm" -wb ''' + str(wb) + ''' -wa ''' + str(wa) + ''' -sp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/evaluation/mimic_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.json;'''
        )
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------- wb: 30 --- wa: 30 -------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2024-09-16 11:19:55,732 - EHR-ML - INFO - Parsing command line arguments
# 2024-09-16 11:19:55,733 - EHR-ML - INFO - args.data_file: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/experiments/inter_source_validation/data/data_matrix_mimic.csv
# 2024-09-16 11:19:55,733 - EHR-ML - INFO - args.target_column: death_0_30_adm
# 2024-09-16 11:19:55,733 - EHR-ML - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# ...

# %% [markdown]
# ## Build mortality prediction model using eICU data

# %%
import os


for (wb, wa) in [(30, 30)]:
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------- wb: ' + str(wb) + ' --- wa: ' + str(wa) + ' -------------------------------------------------------------')
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_ML_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrml.ensemble.Build ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/data/data_matrix_eicu.csv -tc "death_0_30_adm" -ic "person_id" "visit_occurrence_id" -mdc "measurement_date" -adc "visit_start_date_adm" -wb ''' + str(wb) + ''' -wa ''' + str(wa) + ''' -sp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/model/eicu_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.pkl;'''
        )
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------- wb: 30 --- wa: 30 -------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2024-09-16 11:34:48,621 - EHR-ML - INFO - Parsing command line arguments
# 2024-09-16 11:34:48,622 - EHR-ML - INFO - args.data_file: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/experiments/inter_source_validation/data/data_matrix_eicu.csv
# 2024-09-16 11:34:48,622 - EHR-ML - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2024-09-16 11:34:48,622 - EHR-ML - INFO - args.target_column: death_0_30_adm
# ...

# %% [markdown]
# ## Performs predictions for MIMIC using model built on eICU data

# %%
import os


for (wb, wa) in [(30, 30)]:
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------- wb: ' + str(wb) + ' --- wa: ' + str(wa) + ' -------------------------------------------------------------')
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_ML_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrml.ensemble.Predict ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/data/data_matrix_mimic.csv -tc "death_0_30_adm" -ic "person_id" "visit_occurrence_id" -mdc "measurement_date" -adc "visit_start_datetime_adm" -wb ''' + str(wb) + ''' -wa ''' + str(wa)+ ''' -mp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/model/eicu_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.pkl''' + ''' -sp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/prediction/mimic_using_eicu_model_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.csv;'''
        )
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------- wb: 30 --- wa: 30 -------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2024-09-16 12:01:15,110 - EHR-ML - INFO - Parsing command line arguments
# 2024-09-16 12:01:15,112 - EHR-ML - INFO - args.data_file: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/experiments/inter_source_validation/data/data_matrix_mimic.csv
# 2024-09-16 12:01:15,112 - EHR-ML - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2024-09-16 12:01:15,112 - EHR-ML - INFO - args.target_column: death_0_30_adm
# ...

# %% [markdown]
# ## Obtain feature importance of model trained on the eICU data

# %%
import os


for (wb, wa) in [(30, 30)]:
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------- wb: ' + str(wb) + ' --- wa: ' + str(wa) + ' -------------------------------------------------------------')
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_ML_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrml.ensemble.FeatureImportance ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/model/eicu_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.pkl''' + ''' -sp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/feature_importance/eicu_wb_''' + str(wb) + '''_wa_''' + str(wa) + ''';'''
        )
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------- wb: 30 --- wa: 30 -------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2024-09-16 13:13:59,105 - EHR-ML - INFO - Parsing command line arguments
# 2024-09-16 13:13:59,107 - EHR-ML - INFO - args.model_file: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/experiments/inter_source_validation/model/eicu_wb_30_wa_30.pkl
# 2024-09-16 13:13:59,107 - EHR-ML - INFO - args.intermediate: False
# 2024-09-16 13:13:59,107 - EHR-ML - INFO - args.plot: False
# 2024-09-16 13:13:59,107 - EHR-ML - INFO - args.features: 10
# ...

# %% [markdown]
# ## Build mortality prediction model using MIMIC data

# %%
import os


for (wb, wa) in [(30, 30)]:
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------- wb: ' + str(wb) + ' --- wa: ' + str(wa) + ' -------------------------------------------------------------')
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_ML_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrml.ensemble.Build ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/data/data_matrix_mimic.csv -tc "death_0_30_adm" -ic "person_id" "visit_occurrence_id" -mdc "measurement_date" -adc "visit_start_datetime_adm" -wb ''' + str(wb) + ''' -wa ''' + str(wa) + ''' -sp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/model/mimic_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.pkl;'''
        )
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------- wb: 30 --- wa: 30 -------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2024-09-16 12:01:17,803 - EHR-ML - INFO - Parsing command line arguments
# 2024-09-16 12:01:17,804 - EHR-ML - INFO - args.data_file: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/experiments/inter_source_validation/data/data_matrix_mimic.csv
# 2024-09-16 12:01:17,804 - EHR-ML - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2024-09-16 12:01:17,804 - EHR-ML - INFO - args.target_column: death_0_30_adm
# ...

# %% [markdown]
# ## Performs predictions for eICU using model built on MIMIC data

# %%
import os


for (wb, wa) in [(30, 30)]:
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------- wb: ' + str(wb) + ' --- wa: ' + str(wa) + ' -------------------------------------------------------------')
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_ML_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrml.ensemble.Predict ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/data/data_matrix_eicu.csv -tc "death_0_30_adm" -ic "person_id" "visit_occurrence_id" -mdc "measurement_date" -adc "visit_start_date_adm" -wb ''' + str(wb) + ''' -wa ''' + str(wa)+ ''' -mp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/model/mimic_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.pkl''' + ''' -sp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/prediction/eicu_using_mimic_model_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.csv;'''
        )
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------- wb: 30 --- wa: 30 -------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2024-09-16 12:24:58,271 - EHR-ML - INFO - Parsing command line arguments
# 2024-09-16 12:24:58,273 - EHR-ML - INFO - args.data_file: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/experiments/inter_source_validation/data/data_matrix_eicu.csv
# 2024-09-16 12:24:58,273 - EHR-ML - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2024-09-16 12:24:58,273 - EHR-ML - INFO - args.target_column: death_0_30_adm
# ...

# %% [markdown]
# ## Obtain feature importance of model trained on the MIMIC data

# %%
import os


for (wb, wa) in [(30, 30)]:
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------- wb: ' + str(wb) + ' --- wa: ' + str(wa) + ' -------------------------------------------------------------')
    print('--------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_ML_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrml.ensemble.FeatureImportance ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/model/mimic_wb_''' + str(wb) + '''_wa_''' + str(wa) + '''.pkl''' + ''' -sp ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/experiments/inter_source_validation/feature_importance/mimic_wb_''' + str(wb) + '''_wa_''' + str(wa) + ''';'''
        )
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------- wb: 30 --- wa: 30 -------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2024-09-16 13:14:23,212 - EHR-ML - INFO - Parsing command line arguments
# 2024-09-16 13:14:23,213 - EHR-ML - INFO - args.model_file: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/experiments/inter_source_validation/model/mimic_wb_30_wa_30.pkl
# 2024-09-16 13:14:23,213 - EHR-ML - INFO - args.intermediate: False
# 2024-09-16 13:14:23,213 - EHR-ML - INFO - args.plot: False
# 2024-09-16 13:14:23,213 - EHR-ML - INFO - args.features: 10
# ...
