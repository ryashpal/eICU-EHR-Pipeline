# %% [markdown]
# # Final Report Generation

# %% [markdown]
# ## Vitals

# %%
import os


for agg in ['avg', 'min', 'max', 'first', 'last']:
    print('-------------------------------------------------------------------------------------------------------')
    print('Aggregate Function: ', agg)
    print('-------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrqc.plot.ExplorationGraphsPdf'''
        +
        ' ' + os.environ['EICU_EHR_PIPELINE_BASE'] + '/data/plots/combined/vitals_' + agg + '_episode_date.pdf'
        +
        ''' -c '{'''
        +
        ''' "Systemic Mean BP" : ["systemic_mean", "systemic_mean", "systemic_mean"],'''
        +
        ''' "Systemic Diastolic BP" : ["systemic_diastolic", "systemic_diastolic", "systemic_diastolic"],'''
        +
        ''' "Systemic Systolic BP" : ["systemic_systolic", "systemic_systolic", "systemic_systolic"],'''
        +
        ''' "Respiration Rate" : ["respiration", "respiration", "respiration"],'''
        +
        ''' "Heart Rate" : ["heartrate", "heartrate", "heartrate"],'''
        +
        ''' "SAO2" : ["sao2", "sao2", "sao2"]'''
        +
        ''' }' '''
        +
        ''' -sf ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/dropped/vitals_''' + agg + '''_episode_date.csv ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/imputed/vitals_''' + agg + '''_episode_date.csv ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/cleaned/vitals_''' + agg + '''_episode_date.csv'''
        +
        ''' -l "Raw" "Imputed" "Cleaned"'''
        )
# Out:
# -------------------------------------------------------------------------------------------------------
# Aggregate Function:  avg
# -------------------------------------------------------------------------------------------------------
# 2023-11-09 23:12:59,601 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-09 23:12:59,602 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/plots/combined/vitals_avg_episode_date.pdf
# 2023-11-09 23:12:59,602 - EHR-QC - INFO - args.columns: {'Systemic Mean BP': ['systemic_mean', 'systemic_mean', 'systemic_mean'], 'Systemic Diastolic BP': ['systemic_diastolic', 'systemic_diastolic', 'systemic_diastolic'], 'Systemic Systolic BP': ['systemic_systolic', 'systemic_systolic', 'systemic_systolic'], 'Respiration Rate': ['respiration', 'respiration', 'respiration'], 'Heart Rate': ['heartrate', 'heartrate', 'heartrate'], 'SAO2': ['sao2', 'sao2', 'sao2']}
# ...

# %% [markdown]
# ## Labs

# %%
import os


for agg in ['avg', 'min', 'max', 'first', 'last']:
    print('-------------------------------------------------------------------------------------------------------')
    print('Aggregate Function: ', agg)
    print('-------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrqc.plot.ExplorationGraphsPdf'''
        +
        ' ' + os.environ['EICU_EHR_PIPELINE_BASE'] + '/data/plots/combined/labs_' + agg + '_episode_date.pdf'
        +
        ''' -c '{'''
        +
        ''' "Sodium level" : ["Sodium level", "Sodium level", "Sodium level"],'''
        +
        ''' "Blood urea nitrogen" : ["Blood urea nitrogen", "Blood urea nitrogen", "Blood urea nitrogen"],'''
        +
        ''' "Creatinine level" : ["Creatinine level", "Creatinine level", "Creatinine level"],'''
        +
        ''' "Potassium level" : ["Potassium level", "Potassium level", "Potassium level"],'''
        +
        ''' "Chloride" : ["Chloride", "Chloride", "Chloride"],'''
        +
        ''' "Hematocrit" : ["Hematocrit", "Hematocrit", "Hematocrit"],'''
        +
        ''' "Haemoglobin estimation" : ["Haemoglobin estimation", "Haemoglobin estimation", "Haemoglobin estimation"],'''
        +
        ''' "Platelet count" : ["Platelet count", "Platelet count", "Platelet count"],'''
        +
        ''' "Red blood cell count" : ["Red blood cell count", "Red blood cell count", "Red blood cell count"],'''
        +
        ''' "Calcium level" : ["Calcium level", "Calcium level", "Calcium level"],'''
        +
        ''' "MCV - Mean corpuscular volume" : ["MCV - Mean corpuscular volume", "MCV - Mean corpuscular volume", "MCV - Mean corpuscular volume"],'''
        +
        ''' "MCHC - Mean corpuscular haemoglobin concentration" : ["MCHC - Mean corpuscular haemoglobin concentration", "MCHC - Mean corpuscular haemoglobin concentration", "MCHC - Mean corpuscular haemoglobin concentration"],'''
        +
        ''' "MCH - Mean corpuscular haemoglobin" : ["MCH - Mean corpuscular haemoglobin", "MCH - Mean corpuscular haemoglobin", "MCH - Mean corpuscular haemoglobin"],'''
        +
        ''' "White blood cell count" : ["White blood cell count", "White blood cell count", "White blood cell count"],'''
        +
        ''' "Red blood cell distribution width" : ["Red blood cell distribution width", "Red blood cell distribution width", "Red blood cell distribution width"],'''
        +
        ''' "Glucose level" : ["Glucose level", "Glucose level", "Glucose level"],'''
        +
        ''' "Bicarbonate level" : ["Bicarbonate level", "Bicarbonate level", "Bicarbonate level"],'''
        +
        ''' "Anion gap" : ["Anion gap", "Anion gap", "Anion gap"]'''
        +
        ''' }' '''
        +
        ''' -sf ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/dropped/labs_''' + agg + '''_episode_date.csv ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/imputed/labs_''' + agg + '''_episode_date.csv ''' + os.environ['EICU_EHR_PIPELINE_BASE'] + '''/data/cleaned/labs_''' + agg + '''_episode_date.csv'''
        +
        ''' -l "Raw" "Imputed" "Cleaned"'''
        )
# Out:
# -------------------------------------------------------------------------------------------------------
# Aggregate Function:  avg
# -------------------------------------------------------------------------------------------------------
# 2023-11-09 23:14:01,830 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-09 23:14:01,831 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/eICU-EHR-Pipeline/data/plots/combined/labs_avg_episode_date.pdf
# ...
